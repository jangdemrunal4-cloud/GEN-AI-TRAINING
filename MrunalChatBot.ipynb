# %%
#Data Loading first steps
from langchain_community.document_loaders import TextLoader
loadder = TextLoader("rep.txt",encoding="utf-8")
loadder

# %%
pip install langchain_community

# %%
text_document = loadder.load()
text_document
# Out:
# [Document(metadata={'source': 'rep.txt'}, page_content='Using aluminium—whether as metallic filings, lathe waste, or industrial dross—as a partial replacement for natural sand (fine aggregate) is an active area of research in sustainable concrete technology.While replacing sand with industrial waste reduces mining demand and landfill volume, substituting fine aggregate with metallic aluminium introduces significant chemical and physical challenges that fundamentally alter the concrete matrix.1. The Core Chemical Challenge: Hydrogen Gas GenerationUnlike inert silica sand, metallic aluminium reacts vigorously in the highly alkaline environment of hydrating Portland cement. Cement hydration releases calcium hydroxide ($\\text{Ca(OH)}_2$), which reacts with elemental aluminium to produce hydrogen gas ($\\text{H}_2$):$$2\\text{Al} + \\text{Ca(OH)}_2 + 6\\text{H}_2\\text{O} \\rightarrow \\text{Ca}[\\text{Al(OH)}_4]_2 + 3\\text{H}_2 \\uparrow$$Entrapped Micro-Voids: The escaping hydrogen ga
# ...

# %%
#Text spiltter
from langchain_text_splitters import RecursiveCharacterTextSplitter

textSplitter = RecursiveCharacterTextSplitter(chunk_size=200,chunk_overlap=20)

finalDocuments = textSplitter.split_documents(text_document)
finalDocuments
# Out:
# [Document(metadata={'source': 'rep.txt'}, page_content='Using aluminium—whether as metallic filings, lathe waste, or industrial dross—as a partial replacement for natural sand (fine aggregate) is an active area of research in sustainable concrete'),
#  Document(metadata={'source': 'rep.txt'}, page_content='concrete technology.While replacing sand with industrial waste reduces mining demand and landfill volume, substituting fine aggregate with metallic aluminium introduces significant chemical and'),
#  Document(metadata={'source': 'rep.txt'}, page_content='chemical and physical challenges that fundamentally alter the concrete matrix.1. The Core Chemical Challenge: Hydrogen Gas GenerationUnlike inert silica sand, metallic aluminium reacts vigorously in'),
# ...

# %%
# If finalDocuments is a list of Document objects:
texts = [doc.page_content for doc in finalDocuments]

# %%
from langchain_huggingface import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 90.9MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# ...

# %%
pip install langchain_huggingface

# %%
print(embeddings)
# Out:
# model_name='sentence-transformers/all-MiniLM-L6-v2' cache_folder=None model_kwargs={} encode_kwargs={} query_encode_kwargs={} multi_process=False show_progress=False

# %%
# vector Store in DB
from langchain_community.vectorstores import FAISS
db = FAISS.from_documents(finalDocuments, embeddings)
db

# %%
pip install langchain_community.vectorstore
# Out:
# ERROR: Could not find a version that satisfies the requirement langchain_community.vectorstore (from versions: none)
# ERROR: No matching distribution found for langchain_community.vectorstore

# %%
pip install faiss-cpu
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.5/18.5 MB 40.6 MB/s eta 0:00:00
# ...

# %%
query = input("ask any question ? : ")
docs = db.similarity_search(query)
for i in range(len(docs)):
    print(docs[i].page_content)
# Out:
# ask any question ? : advantages of aluminium in concrete
# Helps reduce the use of natural river sand and promotes recycling of aluminum waste, making it an environmentally friendly construction material.
# Advantages of Using This Concrete
# Using aluminium—whether as metallic filings, lathe waste, or industrial dross—as a partial replacement for natural sand (fine aggregate) is an active area of research in sustainable concrete
# The main real-life challenges are obtaining a consistent, properly processed aluminum waste source, preventing unwanted reactions (especially with metallic aluminum), and ensuring that the concrete
# The Advantages1. Controlled Self-Foaming for Lightweight ConcreteWhen metallic aluminium reacts with the calcium hydroxide ($\text{Ca(OH)}_2$) produced during cement hydration, it releases hydrogen
